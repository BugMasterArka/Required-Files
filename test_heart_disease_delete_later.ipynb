# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D:/heart disease/heart_2020_cleaned.csv')
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
fig, axs = plt.subplots(4,3,figsize=(8,6))
plt.pie(axes=axs[0,0],labels=df['HeartDisease'].value_counts().index,values=df['HeartDisease'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ARKALO~1\AppData\Local\Temp/ipykernel_12960/1904641937.py in <module>
#       1 fig, axs = plt.subplots(4,3,figsize=(8,6))
# ----> 2 plt.pie(axes=axs[0,0],labels=df['HeartDisease'].value_counts().index,values=df['HeartDisease'].value_counts())
#
# TypeError: pie() got an unexpected keyword argument 'axes'
